# %% [markdown]
# # Wide World Importers DataSet Analysis <br>
# This project was derived from the Microsoft Wide World Importers dataset ( not the DW) which can be found at: <br>
# <https://github.com/Microsoft/sql-server-samples/releases/tag/wide-world-importers-v1.0>

# %%
import pandas as pd
from pandasql import sqldf
import os

# %%
table_extracts = os.path.realpath(r'../table_extracts')

# %%
fact_order = pd.read_parquet(os.path.join(table_extracts, 'Fact_Order.parquet'))

# %%
fact_order.head()
# Out:
#    OrderID  CustomerID  SalespersonPersonID   OrderDate ExpectedDeliveryDate  \
# 0        1         832                    2  2013-01-01           2013-01-02
# 1        2         803                    8  2013-01-01           2013-01-02
# 2        2         803                    8  2013-01-01           2013-01-02
# 3        3         105                    7  2013-01-01           2013-01-02
# 4        4          57                   16  2013-01-01           2013-01-02
#
#    CustomerPurchaseOrderNumber  OrderLineID  StockItemID  Quantity  UnitPrice  \
# 0                        12126            2           67        10      230.0
# 1                        15342            3           50         9       13.0
# 2                        15342            6           10         9       32.0
# 3                        12211            9          114         3       30.0
# 4                        17129           11          206        96        2.7
#
#    TaxRate  Subtotal    Total
# ...
